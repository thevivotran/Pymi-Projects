# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.rand(10, 4))

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
v = np.array([1,2,3])

# %%
type(v)
# Out:
# numpy.ndarray

# %%
ndarray?
# Out:
# Object `ndarray` not found.

# %%
numpy.ndarray?
# Out:
# Object `numpy.ndarray` not found.

# %%
A = np.array([[1,2,3],
              [4,5,0]])

# %%
A
# Out:
# array([[1, 2, 3],
#        [4, 5, 0]])

# %%
B = np.array([[3,2,1],
             [1,0,5]]); B
# Out:
# array([[3, 2, 1],
#        [1, 0, 5]])

# %%
A + B
# Out:
# array([[4, 4, 4],
#        [5, 5, 5]])

# %%
A * B
# Out:
# array([[3, 4, 3],
#        [4, 0, 0]])

# %%
3 * A
# Out:
# array([[ 3,  6,  9],
#        [12, 15,  0]])

# %%
A * 3
# Out:
# array([[ 3,  6,  9],
#        [12, 15,  0]])

# %%
A
# Out:
# array([[1, 2, 3],
#        [4, 5, 0]])

# %%
A / 4
# Out:
# array([[0.25, 0.5 , 0.75],
#        [1.  , 1.25, 0.  ]])

# %%
A % B
# Out:
# c:\users\ftt.vi.vo\vivo-env\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in remainder
#   """Entry point for launching an IPython kernel.
# array([[1, 0, 0],
#        [0, 0, 0]], dtype=int32)

# %%
B / A
# Out:
# c:\users\ftt.vi.vo\vivo-env\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# array([[3.        , 1.        , 0.33333333],
#        [0.25      , 0.        ,        inf]])

# %%
B / A
# Out:
# c:\users\ftt.vi.vo\vivo-env\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# array([[3.        , 1.        , 0.33333333],
#        [0.25      , 0.        ,        inf]])

# %%
B % A
# Out:
# c:\users\ftt.vi.vo\vivo-env\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in remainder
#   """Entry point for launching an IPython kernel.
# array([[0, 0, 1],
#        [1, 0, 0]], dtype=int32)

# %%
A ** (-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-5920cd76b2d7> in <module>
# ----> 1 A ** (-1)
#
# ValueError: Integers to negative integer powers are not allowed.

# %%
 A
# Out:
# array([[1, 2, 3],
#        [4, 5, 0]])

# %%
B
# Out:
# array([[3, 2, 1],
#        [1, 0, 5]])

# %%
len(A)
# Out:
# 2

# %%
C = np.array([[1,2], [3,4], [5,6]])

# %%
C.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-45af564abff8> in <module>
# ----> 1 C.shape()
#
# TypeError: 'tuple' object is not callable

# %%
C.shape
# Out:
# (3, 2)

# %%
A * B
# Out:
# array([[3, 4, 3],
#        [4, 0, 0]])

# %%
A
# Out:
# array([[1, 2, 3],
#        [4, 5, 0]])

# %%
B
# Out:
# array([[3, 2, 1],
#        [1, 0, 5]])

# %%
A * C
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-7775f665b7b1> in <module>
# ----> 1 A * C
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,2)

# %%
C = np.array([[1,0], [2,1], [3,0]])

# %%
A.dot(C)
# Out:
# array([[14,  2],
#        [14,  5]])

# %%
A @ C
# Out:
# array([[14,  2],
#        [14,  5]])

# %%
v = np.array([1,2,3])

# %%
v = np.array([[1],
              [2],
              [3]])

# %%
v
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
A @ v
# Out:
# array([[14],
#        [14]])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.ones((2,3)) * 5 - 2
# Out:
# array([[3., 3., 3.],
#        [3., 3., 3.]])

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.random.seed(42)

# %%
np.random.rand(3, 4)
# Out:
# array([[0.37454012, 0.95071431, 0.73199394, 0.59865848],
#        [0.15601864, 0.15599452, 0.05808361, 0.86617615],
#        [0.60111501, 0.70807258, 0.02058449, 0.96990985]])

# %%
x = [1,2,3,4]

# %%
y = 2x+1
# Out:
#   File "<ipython-input-87-d99c3247568d>", line 1
#     y = 2x+1
#          ^
# SyntaxError: invalid syntax

# %%
x = np.array([1,2,3,4])

# %%
y = 2*x+1

# %%
y
# Out:
# array([3, 5, 7, 9])

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x, y)
plt.plot(x, x*2)
plt.legend(["y=2x+1", "y=x*2"])
plt.title("Do thi dep nhat")
# Out:
# Text(0.5, 1.0, 'Do thi dep nhat')

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
y = x*x

# %%
plt.plot(x,y)

# %%
x = np.linspace(-10, 10, num=100)

# %%
plt.plot(x, x**2)
plt.plot(x, [80 for i in x])

# %%
import math

# %%
plt.plot(x, math.sin(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-c36ed9b3b555> in <module>
# ----> 1 plt.plot(x, math.sin(x))
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
x = np.linspace(-5, 5, num=100)
y = np.linspace(-1, 1, num=100)

# %%
plt.plot(x, [math.sin(i) for i in x])
plt.plot(x, [math.cos(i) for i in x])
plt.plot(x, [0 for i in x])
for num in range(-5, 5):
    plt.plot([num for i in y], y)

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.DataFrame(data=np.random.rand(30, 4),
                  columns=['APPLE', 'GOOGLE', 'PYMI', 'VIVO'])
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
tables = pd.read_html("https://en.wikipedia.org/wiki/Minnesota",
         match="Election results from statewide races")
len(tables)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-151-6c68b371522b> in <module>
#       1 tables = pd.read_html("https://en.wikipedia.org/wiki/Minnesota",
# ----> 2          match="Election results from statewide races")
#       3 len(tables)
#
# c:\users\ftt.vi.vo\vivo-env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# c:\users\ftt.vi.vo\vivo-env\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1099         na_values=na_values,
# ...

# %%
# !pip install lxml

# %%
import pandas as pd

# %%
tables = pd.read_html("https://en.wikipedia.org/wiki/Minnesota",
         match="Election results from statewide races")
len(tables)
# Out:
# 1

# %%
tables[0]
# Out:
#     Year     Office    GOP    DFL Others
# 0   2018   Governor  42.4%  53.9%   3.7%
# 1   2018    Senator  36.2%  60.3%   3.4%
# 2   2018    Senator  42.4%  53.0%   4.6%
# 3   2016  President  44.9%  46.4%   8.6%
# 4   2014   Governor  44.5%  50.1%   5.4%
# 5   2014    Senator  42.9%  53.2%   3.9%
# 6   2012  President  45.1%  52.8%   2.1%
# 7   2012    Senator  30.6%  65.3%   4.1%
# 8   2010   Governor  43.2%  43.7%  13.1%
# 9   2008  President  43.8%  54.1%   2.1%
# 10  2008    Senator  42.0%  42.0%  16.0%
# 11  2006   Governor  46.7%  45.7%   7.6%
# 12  2006    Senator  37.9%  58.1%   4.0%
# 13  2004  President  47.6%  51.1%   1.3%
# 14  2002   Governor  44.4%  33.5%  22.1%
# 15  2002    Senator  49.5%  47.3%   1.0%
# 16  2000  President  45.5%  47.9%   6.6%
# 17  2000    Senator  43.3%  48.8%   7.9%
# 18  1998   Governor  34.3%  28.1%  37.6%
# 19  1996  President  35.0%  51.1%  13.9%
# 20  1996    Senator  41.3%  50.3%   8.4%
# 21  1994   Governor  63.3%  34.1%   2.6%
# ...

# %%
df = pd.DataFrame(data=np.random.rand(300, 3),
                  columns=['APPLE', 'GOOGLE', 'PYMI'])
df.head(3)
# Out:
#       APPLE    GOOGLE      PYMI
# 0  0.302021  0.528442  0.003096
# 1  0.546175  0.600608  0.850351
# 2  0.808797  0.216315  0.949671

# %%
df.tail(3)
# Out:
#         APPLE    GOOGLE      PYMI
# 297  0.708727  0.540469  0.874821
# 298  0.683609  0.483097  0.893735
# 299  0.133596  0.986074  0.557644

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   APPLE   300 non-null    float64
#  1   GOOGLE  300 non-null    float64
#  2   PYMI    300 non-null    float64
# dtypes: float64(3)
# memory usage: 7.2 KB

# %%
df
# Out:
#         APPLE    GOOGLE      PYMI
# 0    0.302021  0.528442  0.003096
# 1    0.546175  0.600608  0.850351
# 2    0.808797  0.216315  0.949671
# 3    0.559599  0.339141  0.756019
# 4    0.221283  0.691155  0.879411
# ..        ...       ...       ...
# 295  0.798974  0.068730  0.054382
# 296  0.866591  0.953291  0.454029
# 297  0.708727  0.540469  0.874821
# 298  0.683609  0.483097  0.893735
# 299  0.133596  0.986074  0.557644
#
# [300 rows x 3 columns]

# %%
df.describe()
# Out:
#             APPLE      GOOGLE        PYMI
# count  300.000000  300.000000  300.000000
# mean     0.494128    0.493594    0.464653
# std      0.278480    0.288041    0.274383
# min      0.001170    0.002282    0.003096
# 25%      0.271549    0.248022    0.230627
# 50%      0.502572    0.494474    0.488164
# 75%      0.708683    0.724283    0.667837
# max      0.998441    0.997542    0.998482

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'APPLE'}>,
#         <AxesSubplot:title={'center':'GOOGLE'}>],
#        [<AxesSubplot:title={'center':'PYMI'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df = pd.DataFrame(data=np.random.rand(300, 3),
                  columns=['APPLE', 'GOOGLE', 'PYMI'],
                  index=pd.date_range(start='2020-08-20', periods=300)
                 )

# %%
df
# Out:
#                APPLE    GOOGLE      PYMI
# 2020-08-20  0.708563  0.170537  0.872949
# 2020-08-21  0.370391  0.555443  0.018089
# 2020-08-22  0.361986  0.326891  0.953801
# 2020-08-23  0.439037  0.696599  0.717888
# 2020-08-24  0.649479  0.164195  0.697361
# ...              ...       ...       ...
# 2021-06-11  0.920073  0.512462  0.244326
# 2021-06-12  0.710896  0.574038  0.453139
# 2021-06-13  0.352038  0.722365  0.522009
# 2021-06-14  0.579456  0.349628  0.063902
# 2021-06-15  0.347299  0.882173  0.137049
#
# [300 rows x 3 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df[df['PYMI'] > 0.5].head(3)
# Out:
#                APPLE    GOOGLE      PYMI
# 2020-08-20  0.708563  0.170537  0.872949
# 2020-08-22  0.361986  0.326891  0.953801
# 2020-08-23  0.439037  0.696599  0.717888

# %%
df[(df['PYMI'] > 0.5) & (df['GOOGLE'] > 0.6)]
# Out:
#                APPLE    GOOGLE      PYMI
# 2020-08-23  0.439037  0.696599  0.717888
# 2020-08-27  0.172606  0.756239  0.989261
# 2020-08-31  0.305695  0.843350  0.983007
# 2020-09-14  0.070899  0.835762  0.809852
# 2020-09-20  0.073209  0.850785  0.507930
# 2020-09-30  0.434724  0.708412  0.721361
# 2020-10-21  0.407086  0.880534  0.635973
# 2020-11-03  0.588597  0.657401  0.558168
# 2020-11-16  0.381650  0.862485  0.673731
# 2020-11-24  0.842350  0.995119  0.906107
# 2020-11-25  0.674682  0.941009  0.635684
# 2020-12-05  0.690269  0.919868  0.558017
# 2020-12-07  0.682027  0.815069  0.856855
# 2020-12-12  0.001810  0.706750  0.896650
# 2020-12-18  0.473981  0.936216  0.737344
# 2020-12-21  0.533754  0.722154  0.610397
# 2020-12-22  0.513917  0.617624  0.977850
# 2020-12-31  0.727148  0.756950  0.955133
# 2021-01-03  0.610592  0.630550  0.907317
# 2021-01-05  0.840861  0.784334  0.805480
# 2021-01-09  0.238739  0.830273  0.766631
# 2021-01-14  0.545974  0.648905  0.573688
# ...

# %%
df.iloc[0,0] = 10

# %%
df
# Out:
#                 APPLE    GOOGLE      PYMI
# 2020-08-20  10.000000  0.170537  0.872949
# 2020-08-21   0.370391  0.555443  0.018089
# 2020-08-22   0.361986  0.326891  0.953801
# 2020-08-23   0.439037  0.696599  0.717888
# 2020-08-24   0.649479  0.164195  0.697361
# ...               ...       ...       ...
# 2021-06-11   0.920073  0.512462  0.244326
# 2021-06-12   0.710896  0.574038  0.453139
# 2021-06-13   0.352038  0.722365  0.522009
# 2021-06-14   0.579456  0.349628  0.063902
# 2021-06-15   0.347299  0.882173  0.137049
#
# [300 rows x 3 columns]

# %%
df.loc['2020-08-20', 'APPLE']
# Out:
# 10.0

# %%
df.iloc[0:3, -2:]
# Out:
#               GOOGLE      PYMI
# 2020-08-20  0.170537  0.872949
# 2020-08-21  0.555443  0.018089
# 2020-08-22  0.326891  0.953801

# %%
df.sum(axis=1)
# Out:
# 2020-08-20    11.043486
# 2020-08-21     0.943923
# 2020-08-22     1.642678
# 2020-08-23     1.853525
# 2020-08-24     1.511035
#                 ...
# 2021-06-11     1.676861
# 2021-06-12     1.738074
# 2021-06-13     1.596412
# 2021-06-14     0.992987
# 2021-06-15     1.366521
# Freq: D, Length: 300, dtype: float64

# %%
df['Tong'] = df.sum(axis=1)

# %%
df
# Out:
#                 APPLE    GOOGLE      PYMI       Tong
# 2020-08-20  10.000000  0.170537  0.872949  11.043486
# 2020-08-21   0.370391  0.555443  0.018089   0.943923
# 2020-08-22   0.361986  0.326891  0.953801   1.642678
# 2020-08-23   0.439037  0.696599  0.717888   1.853525
# 2020-08-24   0.649479  0.164195  0.697361   1.511035
# ...               ...       ...       ...        ...
# 2021-06-11   0.920073  0.512462  0.244326   1.676861
# 2021-06-12   0.710896  0.574038  0.453139   1.738074
# 2021-06-13   0.352038  0.722365  0.522009   1.596412
# 2021-06-14   0.579456  0.349628  0.063902   0.992987
# 2021-06-15   0.347299  0.882173  0.137049   1.366521
#
# [300 rows x 4 columns]

# %%
df['PYMI'] = df['PYMI'] * 10

# %%
df
# Out:
#                 APPLE    GOOGLE      PYMI       Tong
# 2020-08-20  10.000000  0.170537  8.729489  11.043486
# 2020-08-21   0.370391  0.555443  0.180886   0.943923
# 2020-08-22   0.361986  0.326891  9.538006   1.642678
# 2020-08-23   0.439037  0.696599  7.178883   1.853525
# 2020-08-24   0.649479  0.164195  6.973614   1.511035
# ...               ...       ...       ...        ...
# 2021-06-11   0.920073  0.512462  2.443260   1.676861
# 2021-06-12   0.710896  0.574038  4.531395   1.738074
# 2021-06-13   0.352038  0.722365  5.220086   1.596412
# 2021-06-14   0.579456  0.349628  0.639024   0.992987
# 2021-06-15   0.347299  0.882173  1.370495   1.366521
#
# [300 rows x 4 columns]

# %%
df.head(3)
# Out:
#                 APPLE    GOOGLE      PYMI       Tong
# 2020-08-20  10.000000  0.170537  8.729489  11.043486
# 2020-08-21   0.370391  0.555443  0.180886   0.943923
# 2020-08-22   0.361986  0.326891  9.538006   1.642678

# %%
def chanle(n):
    n = int(n)
    if n % 2 == 0:
        return 'chan'
    else:
        return 'le'

# %%
df['Tong'] = df['Tong'].apply(chanle)

# %%
df
# Out:
#                 APPLE    GOOGLE      PYMI  Tong
# 2020-08-20  10.000000  0.170537  8.729489    le
# 2020-08-21   0.370391  0.555443  0.180886  chan
# 2020-08-22   0.361986  0.326891  9.538006    le
# 2020-08-23   0.439037  0.696599  7.178883    le
# 2020-08-24   0.649479  0.164195  6.973614    le
# ...               ...       ...       ...   ...
# 2021-06-11   0.920073  0.512462  2.443260    le
# 2021-06-12   0.710896  0.574038  4.531395    le
# 2021-06-13   0.352038  0.722365  5.220086    le
# 2021-06-14   0.579456  0.349628  0.639024  chan
# 2021-06-15   0.347299  0.882173  1.370495    le
#
# [300 rows x 4 columns]

# %%
df.sort_values(by='APPLE', ascending=False)
# Out:
#                 APPLE    GOOGLE      PYMI  Tong
# 2020-08-20  10.000000  0.170537  8.729489    le
# 2020-12-27   0.997222  0.165121  1.027978    le
# 2021-05-02   0.988537  0.812232  1.418617    le
# 2021-04-01   0.984764  0.260725  7.224486    le
# 2021-05-29   0.981168  0.091321  4.565502    le
# ...               ...       ...       ...   ...
# 2021-04-02   0.013463  0.535087  0.172058  chan
# 2021-03-21   0.006222  0.433218  4.518875  chan
# 2021-04-14   0.003139  0.271529  1.291873  chan
# 2020-12-12   0.001810  0.706750  8.966499    le
# 2021-01-27   0.000110  0.032952  6.169044  chan
#
# [300 rows x 4 columns]

# %%
df[df['Tong'] == 'chan']
# Out:
#                APPLE    GOOGLE      PYMI  Tong
# 2020-08-21  0.370391  0.555443  0.180886  chan
# 2020-08-25  0.491944  0.223769  1.954770  chan
# 2020-08-31  0.305695  0.843350  9.830067  chan
# 2020-09-01  0.482348  0.087807  0.586084  chan
# 2020-09-02  0.756144  0.956128  4.409902  chan
# ...              ...       ...       ...   ...
# 2021-05-25  0.618996  0.109913  0.692030  chan
# 2021-06-05  0.875887  0.723537  6.226304  chan
# 2021-06-06  0.104892  0.265867  4.122182  chan
# 2021-06-09  0.338069  0.172899  0.414319  chan
# 2021-06-14  0.579456  0.349628  0.639024  chan
#
# [89 rows x 4 columns]

# %%
df.to_csv('hihi.csv')

# %%
df2 = pd.read_csv('hihi.csv', index_col=0)

# %%
df2
# Out:
#                 APPLE    GOOGLE      PYMI  Tong
# 2020-08-20  10.000000  0.170537  8.729489    le
# 2020-08-21   0.370391  0.555443  0.180886  chan
# 2020-08-22   0.361986  0.326891  9.538006    le
# 2020-08-23   0.439037  0.696599  7.178883    le
# 2020-08-24   0.649479  0.164195  6.973614    le
# ...               ...       ...       ...   ...
# 2021-06-11   0.920073  0.512462  2.443260    le
# 2021-06-12   0.710896  0.574038  4.531395    le
# 2021-06-13   0.352038  0.722365  5.220086    le
# 2021-06-14   0.579456  0.349628  0.639024  chan
# 2021-06-15   0.347299  0.882173  1.370495    le
#
# [300 rows x 4 columns]

# %%
df.groupby('Tong').count()['PYMI'].plot.pie()
# Out:
# <AxesSubplot:ylabel='PYMI'>
